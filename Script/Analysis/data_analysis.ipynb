# %%
#  Mount google drive 
from google.colab import drive
drive.mount('/content/drive')

print("Google Drive Mount Successfully :) ")
# Out:
# Mounted at /content/drive
# Google Drive Mount Successfully :)

# %%
# Import required module 
from pyspark.sql import SparkSession
from pyspark.sql import functions as F 
from pyspark.sql import types as T 

print("Print All required module are successfully import")
# Out:
# Print All required module are successfully import

# %%
# Building spark Session 
spark = (
    SparkSession.builder
    .appName("MyDataset")
    .getOrCreate()
)

print("Spark Session Build Successfully")
# Out:
# Spark Session Build Successfully

# %%
# Data Lead successfully 
df = spark.read.csv(
    "/content/drive/MyDrive/Project dataset/bronze/BusinessDW/CRM/cust_info.csv",
    header=True,
    inferSchema=True
)

print("Dataset cust_info load successfully ")
# Out:
# Dataset cust_info load successfully

# %%
df.show(10, truncate=False)
# Out:
# +------+----------+-------------+------------+------------------+--------+---------------+
# |cst_id|cst_key   |cst_firstname|cst_lastname|cst_marital_status|cst_gndr|cst_create_date|
# +------+----------+-------------+------------+------------------+--------+---------------+
# |11000 |AW00011000| Jon         |Yang        |M                 |M       |2025-10-06     |
# |11001 |AW00011001|Eugene       |Huang       |S                 |M       |2025-10-06     |
# |11002 |AW00011002|Ruben        | Torres     |M                 |M       |2025-10-06     |
# |11003 |AW00011003|Christy      |  Zhu       |S                 |F       |2025-10-06     |
# |11004 |AW00011004| Elizabeth   |Johnson     |S                 |F       |2025-10-06     |
# |11005 |AW00011005|Julio        |Ruiz        |S                 |M       |2025-10-06     |
# |11006 |AW00011006|Janet        |Alvarez     |S                 |F       |2025-10-06     |
# ...
